# %%
import pandas as pd
import numpy as np
import pyreadr

# %%
result = pyreadr.read_r("D:/Users/26048898/OneDrive - ARÇELİK A.Ş/Desktop/secim151101g.rda")

# %%
sonuclist = list(result.items())

# %%
df = pd.DataFrame(sonuclist[0][1])

# %%
df
# Out:
#            il  bolge    ilce                cevre cevre_turu  sandik  \
# 0       Adana    1.0  Seyhan                Genel     Toplam  4427.0
# 1       Adana    1.0  Seyhan        İl-İlçe Genel     Toplam  4427.0
# 2       Adana    1.0  Seyhan                Genel     Toplam  1476.0
# 3       Adana    1.0  Seyhan        İl-İlçe Genel     Toplam  1476.0
# 4       Adana    1.0  Seyhan  Ahmet Remzi Yüreğir    Mahalle  3001.0
# ...       ...    ...     ...                  ...        ...     ...
# 177598  Düzce    1.0  Seyhan              Üçköprü        Köy  1053.0
# 177599  Düzce    1.0  Seyhan              Üçköprü        Köy  1054.0
# 177600  Düzce    1.0  Seyhan             Yeniyurt        Köy  1055.0
# 177601  Düzce    1.0  Seyhan            Yeşiltepe        Köy  1056.0
# 177602  Düzce    1.0  Seyhan            Yeşiltepe        Köy  1057.0
#
#         kayitli_secmen  oy_kullanan  gecerli_oy  ak_parti  ...    dsp  dyp  \
# ...
